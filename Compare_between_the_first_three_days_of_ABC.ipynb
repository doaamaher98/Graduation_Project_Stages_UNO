# %% [markdown]
# <a href="https://colab.research.google.com/github/doaamaher98/Graduation_Project_Stages_UNO/blob/main/Compare_between_the_first_three_days_of_ABC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Signals from Flex sensors for Hand Gestures classification**

# %% [markdown]
# # **Introduction**

# %% [markdown]
#  LifeSign Glove that can understand the sign language and could turn in to speech, to unmute the mute.
#
# A trained AI model is made that will understand and translate the sent gestures (values from the sensor readings), into their correct meaning.

# %% [markdown]
# # **Goal:**

# %% [markdown]
# statistical analysis
#
#
# 1.   First day
# 2.   second day
# 3. 2 days
# 4. 3 days

# %% [markdown]
# # **Data Description**

# %% [markdown]
# represent Signals from Flex sensors as a five fingers Thumb,Fore,Middle,Ring and Pinky
#
# Letter meaning of Hand Gesture

# %% [markdown]
# # **Importing Necessary Libraries and datasets**

# %%
# Import pandas library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="ticks", color_codes=True)
import scipy.stats

# %%
# Importing the dataset of first day
dataset1 = pd.read_excel("lifesign_firstday.xlsx")

# %%
# Importing the datasets of second day
dataset2 = pd.read_excel("lifesign_2ndday.xlsx")

# %%
# Importing the dataset of two days
dataset3 = pd.read_excel("lifesign_2day.xlsx")

# %%
# Importing the dataset of Three days
dataset = pd.read_excel("threedays.xlsx")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# # **Descriptive Statistics**

# %% [markdown]
# # **exploratory data analysis(EDA)**

# %% [markdown]
# ![37_1.png](data:image/png;base64,...)

# %% [markdown]
# Now let's go through the features and describe a little. There is a couple of different type of variables, They are...

# %% [markdown]
# # Categorical:
#
# Nominal: variables that have two or more categories, but which do not have an intrinsic order.
#
# **Letter** (A,B and C)
#
# # Quantitative Data:
#
# Continuous Data: It represents the information that could be meaningfully divided into its finer levels. It can be measured on a scale or continuum and can have almost any numeric value.
#
# **Thumb,Fore,Middle,Ring and Pinky**

# %%
dataset.head()
# Out:
#    Thumb   Fore  Middle  Ring  Pinky Letter
# 0     220  -698      84   -64     -9      A
# 1     189  -555      82   -32      8      A
# 2     161  -425      82   -33     20      A
# 3     143  -340      86   -24     26      A
# 4     165  -443      89   -20     29      A

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Thumb   336 non-null    int64
#  1   Fore    336 non-null    int64
#  2   Middle  336 non-null    int64
#  3   Ring    336 non-null    int64
#  4   Pinky   336 non-null    int64
#  5   Letter  336 non-null    object
# dtypes: int64(5), object(1)
# memory usage: 15.9+ KB

# %%
dataset1.describe()
# Out:
#             Thumb         Fore      Middle        Ring       Pinky
# count  112.000000   112.000000  112.000000  112.000000  112.000000
# mean   116.973214  -217.660714   84.383929    3.169643   31.562500
# std     39.839195   185.891645   18.448978   64.154078   45.543521
# min     62.000000 -1008.000000   16.000000 -242.000000 -111.000000
# 25%     86.750000  -296.250000   81.000000  -30.750000   -6.750000
# 50%    106.000000  -167.000000   92.500000    8.500000   29.000000
# 75%    134.250000   -77.250000   98.000000   64.250000   69.000000
# max    286.000000    37.000000  101.000000   84.000000  109.000000

# %%
dataset2.describe()
# Out:
#            Thumb          Fore      Middle        Ring       Pinky
# count  111.000000   111.000000  111.000000  111.000000  111.000000
# mean   176.585586  -495.990991   64.963964  -84.279279   10.279279
# std     50.376666   235.011856   31.198755   72.279278   46.653300
# min     96.000000 -1469.000000 -128.000000 -382.000000 -185.000000
# 25%    145.000000  -609.000000   52.000000 -108.000000  -28.500000
# 50%    165.000000  -443.000000   66.000000  -64.000000   27.000000
# 75%    201.000000  -348.000000   91.000000  -33.000000   43.000000
# max    385.000000  -122.000000  100.000000   -4.000000   93.000000

# %%
dataset3.describe()
# Out:
#            Thumb          Fore      Middle        Ring       Pinky
# count  223.000000   223.000000  223.000000  223.000000  223.000000
# mean   146.645740  -356.201794   74.717489  -40.358744   20.968610
# std     54.253535   253.176094   27.334696   81.036342   47.215663
# min     62.000000 -1469.000000 -128.000000 -382.000000 -185.000000
# 25%    104.000000  -498.000000   60.000000  -88.500000  -11.500000
# 50%    141.000000  -328.000000   84.000000  -33.000000   28.000000
# 75%    177.000000  -157.000000   94.000000    8.500000   49.000000
# max    385.000000    37.000000  101.000000   84.000000  109.000000

# %%
dataset.describe()
# Out:
#            Thumb          Fore      Middle        Ring       Pinky
# count  336.000000   336.000000  336.000000  336.000000  336.000000
# mean   155.797619  -398.934524   70.229167  -64.800595   -3.455357
# std     65.125877   303.965250   29.936518   92.135132   86.272448
# min     62.000000 -1576.000000 -128.000000 -461.000000 -279.000000
# 25%    107.750000  -527.250000   55.000000 -103.500000  -19.000000
# 50%    141.000000  -330.000000   82.000000  -52.000000   25.000000
# 75%    183.250000  -176.250000   93.000000  -10.000000   45.250000
# max    408.000000    37.000000  101.000000   84.000000  109.000000

# %% [markdown]
# ![780px-Sign_language_A.svg.png](data:image/png;base64,...)

# %%
#boxplot
plt.rcParams['figure.figsize'] = (10, 10)
ax = sns.boxplot(x="Letter", y="Fore", data=dataset)
ax = sns.swarmplot(x="Letter", y="Fore", data=dataset, color=".25")

# %%
#boxplot
plt.rcParams['figure.figsize'] = (10, 10)
ax = sns.boxplot(x="Letter", y="Middle", data=dataset)
ax = sns.swarmplot(x="Letter", y="Middle", data=dataset, color=".25")

# %%
#boxplot
plt.rcParams['figure.figsize'] = (10, 10)
ax = sns.boxplot(x="Letter", y="Ring", data=dataset)
ax = sns.swarmplot(x="Letter", y="Ring", data=dataset, color=".25")

# %%
#boxplot
plt.rcParams['figure.figsize'] = (10, 10)
ax = sns.boxplot(x="Letter", y="Pinky", data=dataset)
ax = sns.swarmplot(x="Letter", y="Pinky", data=dataset, color=".25")

# %% [markdown]
# ![A.png](data:image/png;base64,...)

# %% [markdown]
# ![Day1 vs Day2.png](data:image/png;base64,...)

# %% [markdown]
# # **A**

# %% [markdown]
# ![3 dys vs A.png](data:image/png;base64,...)

# %% [markdown]
# # **B**

# %% [markdown]
# ![3dys vs B.png](data:image/png;base64,...)

# %% [markdown]
# # **C**

# %% [markdown]
# ![3dys vs C.png](data:image/png;base64,...)

# %% [markdown]
# # **Correlation vs Association**

# %% [markdown]
# ![1200px-Correlation_examples2.svg.png](data:image/png;base64,...)

# %% [markdown]
# **Data Correlation:** is a way to understand the relationship betweem multiple variables and attributes

# %% [markdown]
# ![0_abk24QJL8-9JKFEz.png](data:image/png;base64,...)

# %% [markdown]
# ![Correlation-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![780px-Sign_language_A.svg.png](data:image/png;base64,...)

# %%
dataset1.corr()
# Out:
#            Thumb      Fore    Middle      Ring     Pinky
#  Thumb  1.000000 -0.999973 -0.094894  0.091380 -0.557742
#  Fore  -0.999973  1.000000  0.095909 -0.089983  0.557611
# Middle -0.094894  0.095909  1.000000  0.841773  0.673643
#  Ring   0.091380 -0.089983  0.841773  1.000000  0.298428
# Pinky  -0.557742  0.557611  0.673643  0.298428  1.000000

# %%
dataset2.corr()
# Out:
#           Thumb       Fore    Middle      Ring     Pinky
# Thumb   1.000000 -0.999987 -0.168369 -0.198184 -0.328203
# Fore   -0.999987  1.000000  0.167491  0.197735  0.327298
# Middle -0.168369  0.167491  1.000000  0.791646  0.340328
# Ring   -0.198184  0.197735  0.791646  1.000000  0.122576
# Pinky  -0.328203  0.327298  0.340328  0.122576  1.000000

# %%
dataset3.corr()
# Out:
#           Thumb       Fore    Middle      Ring     Pinky
# Thumb   1.000000 -0.999987 -0.307962 -0.352527 -0.471109
# Fore   -0.999987  1.000000  0.307826  0.352884  0.470650
# Middle -0.307962  0.307826  1.000000  0.816742  0.489877
# Ring   -0.352527  0.352884  0.816742  1.000000  0.289626
# Pinky  -0.471109  0.470650  0.489877  0.289626  1.000000

# %%
dataset.corr()
# Out:
#           Thumb       Fore    Middle      Ring     Pinky
# Thumb   1.000000 -0.999991 -0.269054 -0.303863 -0.361778
# Fore   -0.999991  1.000000  0.268769  0.303803  0.361360
# Middle -0.269054  0.268769  1.000000  0.820227  0.731463
# Ring   -0.303863  0.303803  0.820227  1.000000  0.593388
# Pinky  -0.361778  0.361360  0.731463  0.593388  1.000000

# %%
plt.rcParams['figure.figsize'] = (40, 41)
sns.pairplot(dataset1, hue = 'Letter', palette = 'husl')
plt.title('Pair plot for the data', fontsize = 40)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (40, 41)
plt.style.use('dark_background')
 
sns.pairplot(dataset2, hue = 'Letter', palette = 'husl')
plt.title('Pair plot for the data', fontsize = 40)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (40, 41)
plt.style.use('dark_background')
 
sns.pairplot(dataset3, hue = 'Letter', palette = 'husl')
plt.title('Pair plot for the data', fontsize = 40)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (40, 41)
plt.style.use('dark_background')
 
sns.pairplot(dataset, hue = 'Letter', palette = 'husl')
plt.title('Pair plot for the data', fontsize = 40)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X= sc.fit_transform(dataset.drop(["Letter"],axis = 1))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1/3,random_state=42, stratify=y)

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf',degree=3)
model.fit(X_train,y_train)

# Predicting the Test set results SVM
y_pred = model.predict(X_test)

#calculate the details SVM
print('train_score svcmodel', model.score(X_train,y_train))
print('test_score svcmodel',model.score(X_test,y_test))
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# train_score svcmodel 0.9285714285714286
# test_score svcmodel 0.9196428571428571
# [[34  3  0]
#  [ 4 33  0]
#  [ 2  0 36]]
